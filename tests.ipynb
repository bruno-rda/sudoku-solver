# %%
from sudoku import Sudoku

# %%
board = [
    ["5","3",".",".","7",".",".",".","."],
    ["6",".",".","1","9","5",".",".","."],
    [".","9","8",".",".",".",".","6","."],
    ["8",".",".",".","6",".",".",".","3"],
    ["4",".",".","8",".","3",".",".","1"],
    ["7",".",".",".","2",".",".",".","6"],
    [".","6",".",".",".",".","2","8","."],
    [".",".",".","4","1","9",".",".","5"],
    [".",".",".",".","8",".",".","7","9"]
]

game = Sudoku(board)
print(game)

print('\nStarting to solve...')
game.solve()
print('Ended solving \n')

print(game)
# Out:
#  5 3 . | . 7 . | . . .
#  6 . . | 1 9 5 | . . .
#  . 9 8 | . . . | . 6 .
# -------+-------+-------
#  8 . . | . 6 . | . . 3
#  4 . . | 8 . 3 | . . 1
#  7 . . | . 2 . | . . 6
# -------+-------+-------
#  . 6 . | . . . | 2 8 .
#  . . . | 4 1 9 | . . 5
#  . . . | . 8 . | . 7 9
#
# Starting to solve...
# Solve took: 0.000166 seconds
#
# Ended solving
#
#  5 3 4 | 6 7 8 | 9 1 2
#  6 7 2 | 1 9 5 | 3 4 8
#  1 9 8 | 3 4 2 | 5 6 7
# -------+-------+-------
#  8 5 9 | 7 6 1 | 4 2 3
#  4 2 6 | 8 5 3 | 7 9 1
#  7 1 3 | 9 2 4 | 8 5 6
# -------+-------+-------
#  9 6 1 | 5 3 7 | 2 8 4
#  2 8 7 | 4 1 9 | 6 3 5
#  3 4 5 | 2 8 6 | 1 7 9

# %%
board = [
    [".",".","9","7","4","8",".",".","."],
    ["7",".",".",".",".",".",".",".","."],
    [".","2",".","1",".","9",".",".","."],
    [".",".","7",".",".",".","2","4","."],
    [".","6","4",".","1",".","5","9","."],
    [".","9","8",".",".",".","3",".","."],
    [".",".",".","8",".","3",".","2","."],
    [".",".",".",".",".",".",".",".","6"],
    [".",".",".","2","7","5","9",".","."]
]

game = Sudoku(board)
print(game)

print('\nStarting to solve...')
game.solve()
print('Ended solving \n')

print(game)
# Out:
#  . . 9 | 7 4 8 | . . .
#  7 . . | . . . | . . .
#  . 2 . | 1 . 9 | . . .
# -------+-------+-------
#  . . 7 | . . . | 2 4 .
#  . 6 4 | . 1 . | 5 9 .
#  . 9 8 | . . . | 3 . .
# -------+-------+-------
#  . . . | 8 . 3 | . 2 .
#  . . . | . . . | . . 6
#  . . . | 2 7 5 | 9 . .
#
# Starting to solve...
# Solve took: 0.000100 seconds
#
# Ended solving
#
#  5 1 9 | 7 4 8 | 6 3 2
#  7 8 3 | 6 5 2 | 4 1 9
#  4 2 6 | 1 3 9 | 8 7 5
# -------+-------+-------
#  3 5 7 | 9 8 6 | 2 4 1
#  2 6 4 | 3 1 7 | 5 9 8
#  1 9 8 | 5 2 4 | 3 6 7
# -------+-------+-------
#  9 7 5 | 8 6 3 | 1 2 4
#  8 3 2 | 4 9 1 | 7 5 6
#  6 4 1 | 2 7 5 | 9 8 3

# %%
board = [
    [".", ".", "4", "3", ".", ".", ".", "9", "."],
    [".", "3", ".", ".", ".", "8", "4", ".", "5"],
    ["9", "5", ".", "4", ".", ".", ".", ".", "."],
    [".", "9", ".", ".", "3", ".", ".", ".", "."],
    [".", ".", ".", "8", ".", ".", "5", ".", "6"],
    [".", ".", ".", ".", "7", ".", ".", "4", "."],
    ["4", ".", "1", "7", ".", "3", ".", ".", "9"],
    [".", "6", "3", ".", ".", ".", "7", "2", "."],
    [".", "2", "9", ".", "4", "6", "1", ".", "."],
]

game = Sudoku(board)
print(game)

print('\nStarting to solve...')
game.solve()
print('Ended solving \n')

print(game)
# Out:
#  . . 4 | 3 . . | . 9 .
#  . 3 . | . . 8 | 4 . 5
#  9 5 . | 4 . . | . . .
# -------+-------+-------
#  . 9 . | . 3 . | . . .
#  . . . | 8 . . | 5 . 6
#  . . . | . 7 . | . 4 .
# -------+-------+-------
#  4 . 1 | 7 . 3 | . . 9
#  . 6 3 | . . . | 7 2 .
#  . 2 9 | . 4 6 | 1 . .
#
# Starting to solve...
# Solve took: 0.000098 seconds
#
# Ended solving
#
#  6 7 4 | 3 5 2 | 8 9 1
#  1 3 2 | 9 6 8 | 4 7 5
#  9 5 8 | 4 1 7 | 3 6 2
# -------+-------+-------
#  8 9 5 | 6 3 4 | 2 1 7
#  2 4 7 | 8 9 1 | 5 3 6
#  3 1 6 | 2 7 5 | 9 4 8
# -------+-------+-------
#  4 8 1 | 7 2 3 | 6 5 9
#  5 6 3 | 1 8 9 | 7 2 4
#  7 2 9 | 5 4 6 | 1 8 3

# %%
board = [
    ["8", ".", ".", ".", ".", ".", ".", ".", "."],
    [".", ".", "3", "6", ".", ".", ".", ".", "."],
    [".", "7", ".", ".", "9", ".", "2", ".", "."],
    [".", "5", ".", ".", ".", "7", ".", ".", "."],
    [".", ".", ".", ".", "4", "5", "7", ".", "."],
    [".", ".", ".", "1", ".", ".", ".", "3", "."],
    [".", ".", "1", ".", ".", ".", ".", "6", "8"],
    [".", ".", "8", "5", ".", ".", ".", "1", "."],
    [".", "9", ".", ".", ".", ".", "4", ".", "."],
]

game = Sudoku(board)
print(game)

print('\nStarting to solve...')
game.solve()
print('Ended solving \n')

print(game)
# Out:
#  8 . . | . . . | . . .
#  . . 3 | 6 . . | . . .
#  . 7 . | . 9 . | 2 . .
# -------+-------+-------
#  . 5 . | . . 7 | . . .
#  . . . | . 4 5 | 7 . .
#  . . . | 1 . . | . 3 .
# -------+-------+-------
#  . . 1 | . . . | . 6 8
#  . . 8 | 5 . . | . 1 .
#  . 9 . | . . . | 4 . .
#
# Starting to solve...
# Solve took: 0.000053 seconds
#
# Ended solving
#
#  8 1 2 | 7 5 3 | 6 4 9
#  9 4 3 | 6 8 2 | 1 7 5
#  6 7 5 | 4 9 1 | 2 8 3
# -------+-------+-------
#  1 5 4 | 2 3 7 | 8 9 6
#  3 6 9 | 8 4 5 | 7 2 1
#  2 8 7 | 1 6 9 | 5 3 4
# -------+-------+-------
#  5 2 1 | 9 7 4 | 3 6 8
#  4 3 8 | 5 2 6 | 9 1 7
#  7 9 6 | 3 1 8 | 4 5 2
